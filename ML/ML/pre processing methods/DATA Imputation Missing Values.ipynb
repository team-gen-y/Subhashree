# %%
import numpy as np
import pandas as pd

data_employee={ 'employee_id':np.arange(1,101),
                'Age':np.random.randint(25,62,size=100),
                'Basic Pay':np.random.randint(15600,67100,size=100),
                'No of Clients':np.random.randint(1,1000,size=100),
                'Years of Service':np.random.randint(0,41,size=100),
                'Performance Score':np.random.randint(0,2,size=100)
              }
df=pd.DataFrame(data_employee,columns=['employee_id','Age','Basic Pay','No of Clients','Years of Service','Performance Score'])            
print(df)
# Out:
#     employee_id  Age  Basic Pay  No of Clients  Years of Service  \
# 0             1   59      45145            286                32
# 1             2   32      22249            910                30
# 2             3   51      26618            345                 2
# 3             4   25      31450            247                23
# 4             5   37      52378            813                28
# 5             6   25      44783            462                 1
# 6             7   50      47352            850                38
# 7             8   48      16245            590                 2
# 8             9   44      35560            661                25
# 9            10   51      22976            840                25
# 10           11   50      25585            941                13
# 11           12   40      53191            953                31
# 12           13   29      33655            643                25
# ...

# %%
df.to_csv('C:/Users/ganapathi raju/Desktop/pre processing methods/emp.csv',sep=',',index=False)

# %%
e=pd.read_csv('C:/Users/ganapathi raju/Desktop/pre processing methods/data_after_missing_values.csv')

# %%
print (e)
# Out:
#     employee_id   Age  Basic Pay  No of Clients  Years of Service  \
# 0             1   NaN        NaN          606.0               NaN
# 1             2   NaN        NaN          116.0              39.0
# 2             3  32.0    37645.0          611.0              16.0
# 3             4  59.0    17423.0          992.0              16.0
# 4             5  34.0    33071.0           56.0              33.0
# 5             6  48.0    40974.0          851.0              34.0
# 6             7  27.0    63160.0          183.0              37.0
# 7             8  42.0    20854.0           92.0              33.0
# 8             9  61.0    18533.0          572.0              11.0
# 9            10  41.0    39972.0          204.0              19.0
# 10           11  56.0    45091.0          690.0               4.0
# 11           12   NaN    51454.0          594.0              11.0
# 12           13  42.0    20790.0          682.0              34.0
# ...

# %%
e['Age']=e['Age'].fillna(100)
e['Basic Pay']=e['Basic Pay'].fillna(1000)
e['No of Clients']=e['No of Clients'].fillna(100)
e['Years of Service']=e['Years of Service'].fillna(50)
print(e)
# Out:
#     employee_id    Age  Basic Pay  No of Clients  Years of Service  \
# 0             1  100.0     1000.0          606.0              50.0
# 1             2  100.0     1000.0          116.0              39.0
# 2             3   32.0    37645.0          611.0              16.0
# 3             4   59.0    17423.0          992.0              16.0
# 4             5   34.0    33071.0           56.0              33.0
# 5             6   48.0    40974.0          851.0              34.0
# 6             7   27.0    63160.0          183.0              37.0
# 7             8   42.0    20854.0           92.0              33.0
# 8             9   61.0    18533.0          572.0              11.0
# 9            10   41.0    39972.0          204.0              19.0
# 10           11   56.0    45091.0          690.0               4.0
# 11           12  100.0    51454.0          594.0              11.0
# 12           13   42.0    20790.0          682.0              34.0
# ...

# %%
e.to_csv('C:/Users/ganapathi raju/Desktop/pre processing methods/PS_1B_1.csv',sep=',',index=False)

# %%
e1=pd.read_csv('C:/Users/ganapathi raju/Desktop/pre processing methods/PS_1B_1.csv')

# %%
print (e1)
# Out:
#     employee_id    Age  Basic Pay  No of Clients  Years of Service  \
# 0             1  100.0     1000.0          606.0              50.0
# 1             2  100.0     1000.0          116.0              39.0
# 2             3   32.0    37645.0          611.0              16.0
# 3             4   59.0    17423.0          992.0              16.0
# 4             5   34.0    33071.0           56.0              33.0
# 5             6   48.0    40974.0          851.0              34.0
# 6             7   27.0    63160.0          183.0              37.0
# 7             8   42.0    20854.0           92.0              33.0
# 8             9   61.0    18533.0          572.0              11.0
# 9            10   41.0    39972.0          204.0              19.0
# 10           11   56.0    45091.0          690.0               4.0
# 11           12  100.0    51454.0          594.0              11.0
# 12           13   42.0    20790.0          682.0              34.0
# ...

# %%
e3=pd.read_csv('C:/Users/ganapathi raju/Desktop/pre processing methods/data_after_missing_values.csv')

# %%
print(e3)
# Out:
#     employee_id   Age  Basic Pay  No of Clients  Years of Service  \
# 0             1   NaN        NaN          606.0               NaN
# 1             2   NaN        NaN          116.0              39.0
# 2             3  32.0    37645.0          611.0              16.0
# 3             4  59.0    17423.0          992.0              16.0
# 4             5  34.0    33071.0           56.0              33.0
# 5             6  48.0    40974.0          851.0              34.0
# 6             7  27.0    63160.0          183.0              37.0
# 7             8  42.0    20854.0           92.0              33.0
# 8             9  61.0    18533.0          572.0              11.0
# 9            10  41.0    39972.0          204.0              19.0
# 10           11  56.0    45091.0          690.0               4.0
# 11           12   NaN    51454.0          594.0              11.0
# 12           13  42.0    20790.0          682.0              34.0
# ...

# %%
e3['Age'].fillna(e['Age'].mean(),inplace=True)
e3['Basic Pay'].fillna(e['Basic Pay'].mean(),inplace=True)
e3['No of Clients'].fillna(e['No of Clients'].mean(),inplace=True)
e3['Years of Service'].fillna(e['Years of Service'].mean(),inplace=True)
print(e3)
# Out:
#     employee_id    Age  Basic Pay  No of Clients  Years of Service  \
# 0             1  47.88   40701.95         606.00             20.37
# 1             2  47.88   40701.95         116.00             39.00
# 2             3  32.00   37645.00         611.00             16.00
# 3             4  59.00   17423.00         992.00             16.00
# 4             5  34.00   33071.00          56.00             33.00
# 5             6  48.00   40974.00         851.00             34.00
# 6             7  27.00   63160.00         183.00             37.00
# 7             8  42.00   20854.00          92.00             33.00
# 8             9  61.00   18533.00         572.00             11.00
# 9            10  41.00   39972.00         204.00             19.00
# 10           11  56.00   45091.00         690.00              4.00
# 11           12  47.88   51454.00         594.00             11.00
# 12           13  42.00   20790.00         682.00             34.00
# ...

# %%
e3.to_csv('C:/Users/ganapathi raju/Desktop/pre processing methods/PS_1B_2.csv',sep=',',index=False)

# %%
e4=pd.read_csv('C:/Users/ganapathi raju/Desktop/pre processing methods//PS_1B_2.csv')

# %%
print(e4)
# Out:
#     employee_id    Age  Basic Pay  No of Clients  Years of Service  \
# 0             1  47.88   40701.95         606.00             20.37
# 1             2  47.88   40701.95         116.00             39.00
# 2             3  32.00   37645.00         611.00             16.00
# 3             4  59.00   17423.00         992.00             16.00
# 4             5  34.00   33071.00          56.00             33.00
# 5             6  48.00   40974.00         851.00             34.00
# 6             7  27.00   63160.00         183.00             37.00
# 7             8  42.00   20854.00          92.00             33.00
# 8             9  61.00   18533.00         572.00             11.00
# 9            10  41.00   39972.00         204.00             19.00
# 10           11  56.00   45091.00         690.00              4.00
# 11           12  47.88   51454.00         594.00             11.00
# 12           13  42.00   20790.00         682.00             34.00
# ...
